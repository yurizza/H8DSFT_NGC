# %% [markdown]
# # Non Graded Challenge 10
#
# - Name  : Cici Yuriza
# - Batch : HCK-005

# %% [markdown]
# #### Loading Data

# %%
# import all libraries
import pandas as pd

# %%
# Loading data
df = pd.read_csv('Dataset/covid_19_indonesia_time_series_all.csv')

# %%
# tampilkan all columns in dataframe
pd.set_option("display.max.columns", None)

# %%
df.head()
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            1             0
# 4              0                 2           43            20
#
#    Total Recovered  Total Active Cases Location Level  City or Regency  \
# 0               75                 -56       Province              NaN
# 1               75                 -54       Province              NaN
# 2                0                   2        Country              NaN
# 3                1                   0       Province              NaN
# 4               75                 -52       Province              NaN
#
#       Province    Country Continent    Island  Time Zone  \
# 0  DKI Jakarta  Indonesia      Asia      Jawa  UTC+07:00
# 1  DKI Jakarta  Indonesia      Asia      Jawa  UTC+07:00
# 2          NaN  Indonesia      Asia       NaN        NaN
# 3         Riau  Indonesia      Asia  Sumatera  UTC+07:00
# 4  DKI Jakarta  Indonesia      Asia      Jawa  UTC+07:00
#
#            Special Status  Total Regencies  Total Cities  Total Districts  \
# 0  Daerah Khusus Ibu Kota                1           5.0               44
# 1  Daerah Khusus Ibu Kota                1           5.0               44
# 2                     NaN              416          98.0             7230
# 3                     NaN               10           2.0              169
# 4  Daerah Khusus Ibu Kota                1           5.0               44
#
#    Total Urban Villages  Total Rural Villages  Area (km2)  Population  \
# 0                 267.0                   NaN         664    10846145
# 1                 267.0                   NaN         664    10846145
# 2                8488.0               74953.0     1916907   265185520
# 3                 268.0                1591.0       87024     6074100
# 4                 267.0                   NaN         664    10846145
#
#    Population Density   Longitude  Latitude  New Cases per Million  \
# 0            16334.31  106.836118 -6.204699                   0.18
# 1            16334.31  106.836118 -6.204699                   0.18
# 2              138.34  113.921327 -0.789275                   0.01
# 3               69.80  101.805109  0.511648                   0.16
# 4            16334.31  106.836118 -6.204699                   0.18
#
#    Total Cases per Million  New Deaths per Million  Total Deaths per Million  \
# 0                     3.60                     0.0                      1.84
# 1                     3.78                     0.0                      1.84
# 2                     0.01                     0.0                      0.00
# 3                     0.16                     0.0                      0.00
# 4                     3.96                     0.0                      1.84
#
#    Total Deaths per 100rb Case Fatality Rate Case Recovered Rate  \
# 0                    0.18             51.28%             192.31%
# 1                    0.18             48.78%             182.93%
# 2                    0.00              0.00%               0.00%
# 3                    0.00              0.00%             100.00%
# 4                    0.18             46.51%             174.42%
#
#    Growth Factor of New Cases  Growth Factor of New Deaths
# 0                         NaN                          NaN
# 1                         1.0                          1.0
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         1.0                          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         31822 non-null  object
#  1   Location ISO Code            31822 non-null  object
#  2   Location                     31822 non-null  object
#  3   New Cases                    31822 non-null  int64
#  4   New Deaths                   31822 non-null  int64
#  5   New Recovered                31822 non-null  int64
#  6   New Active Cases             31822 non-null  int64
#  7   Total Cases                  31822 non-null  int64
#  8   Total Deaths                 31822 non-null  int64
#  9   Total Recovered              31822 non-null  int64
#  10  Total Active Cases           31822 non-null  int64
#  11  Location Level               31822 non-null  object
#  12  City or Regency              0 non-null      float64
#  13  Province                     30893 non-null  object
#  14  Country                      31822 non-null  object
#  15  Continent                    31822 non-null  object
#  16  Island                       30893 non-null  object
#  17  Time Zone                    30893 non-null  object
#  18  Special Status               4558 non-null   object
#  19  Total Regencies              31822 non-null  int64
#  20  Total Cities                 30921 non-null  float64
#  21  Total Districts              31822 non-null  int64
#  22  Total Urban Villages         30918 non-null  float64
#  23  Total Rural Villages         30893 non-null  float64
#  24  Area (km2)                   31822 non-null  int64
#  25  Population                   31822 non-null  int64
#  26  Population Density           31822 non-null  float64
#  27  Longitude                    31822 non-null  float64
#  28  Latitude                     31822 non-null  float64
#  29  New Cases per Million        31822 non-null  float64
#  30  Total Cases per Million      31822 non-null  float64
#  31  New Deaths per Million       31822 non-null  float64
#  32  Total Deaths per Million     31822 non-null  float64
#  33  Total Deaths per 100rb       31822 non-null  float64
#  34  Case Fatality Rate           31822 non-null  object
#  35  Case Recovered Rate          31822 non-null  object
#  36  Growth Factor of New Cases   29883 non-null  float64
#  37  Growth Factor of New Deaths  28375 non-null  float64
# dtypes: float64(14), int64(12), object(12)
# memory usage: 9.2+ MB

# %%
# change type data Date from object to datetime
df['Date'] = pd.to_datetime(df['Date'])

# %%
# make new dataframe, the Location is DKI Jakarta and year >= 2021
df_new = df[['Date',
             'Location',
             'New Cases', 
             'New Deaths',
             'New Recovered',
             'New Active Cases'
             ]].query(("Location == 'DKI Jakarta' & Date.dt.year >= 2021"))
df_new
# Out:
#             Date     Location  New Cases  New Deaths  New Recovered  \
# 10022 2021-01-01  DKI Jakarta       1956          20           1643
# 10057 2021-01-02  DKI Jakarta       1894          26           2280
# 10092 2021-01-03  DKI Jakarta       1658          10           1691
# 10127 2021-01-04  DKI Jakarta       1832          21           2527
# 10162 2021-01-05  DKI Jakarta       1824          19           1339
# ...          ...          ...        ...         ...            ...
# 31652 2022-09-11  DKI Jakarta        855           3           1429
# 31687 2022-09-12  DKI Jakarta         17           3           1350
# 31722 2022-09-13  DKI Jakarta         16           0            313
# 31757 2022-09-14  DKI Jakarta       1228           1             23
# 31792 2022-09-15  DKI Jakarta       1116           0             58
#
#        New Active Cases
# 10022               293
# 10057              -412
# 10092               -43
# 10127              -716
# 10162               466
# ...                 ...
# 31652              -577
# 31687             -1336
# 31722              -297
# 31757              1204
# 31792              1058
#
# [623 rows x 6 columns]

# %%
# reset index from 0
df_new = df_new[df_new["Location"] != None ].reset_index(drop=True)
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623 entries, 0 to 622
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              623 non-null    datetime64[ns]
#  1   Location          623 non-null    object
#  2   New Cases         623 non-null    int64
#  3   New Deaths        623 non-null    int64
#  4   New Recovered     623 non-null    int64
#  5   New Active Cases  623 non-null    int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 29.3+ KB

# %%
# remove column Location
df_new.drop(columns='Location',inplace=True)
df_new
# Out:
#           Date  New Cases  New Deaths  New Recovered  New Active Cases
# 0   2021-01-01       1956          20           1643               293
# 1   2021-01-02       1894          26           2280              -412
# 2   2021-01-03       1658          10           1691               -43
# 3   2021-01-04       1832          21           2527              -716
# 4   2021-01-05       1824          19           1339               466
# ..         ...        ...         ...            ...               ...
# 618 2022-09-11        855           3           1429              -577
# 619 2022-09-12         17           3           1350             -1336
# 620 2022-09-13         16           0            313              -297
# 621 2022-09-14       1228           1             23              1204
# 622 2022-09-15       1116           0             58              1058
#
# [623 rows x 5 columns]

# %%
# set date to be index
df_new.set_index('Date',inplace=True)
df_new
# Out:
#             New Cases  New Deaths  New Recovered  New Active Cases
# Date
# 2021-01-01       1956          20           1643               293
# 2021-01-02       1894          26           2280              -412
# 2021-01-03       1658          10           1691               -43
# 2021-01-04       1832          21           2527              -716
# 2021-01-05       1824          19           1339               466
# ...               ...         ...            ...               ...
# 2022-09-11        855           3           1429              -577
# 2022-09-12         17           3           1350             -1336
# 2022-09-13         16           0            313              -297
# 2022-09-14       1228           1             23              1204
# 2022-09-15       1116           0             58              1058
#
# [623 rows x 4 columns]

# %% [markdown]
# #### Cari Measure of Central Tendency dari data.

# %% [markdown]
# ##### Mean, Modus, Median

# %%
df_new.head(4)
# Out:
#             New Cases  New Deaths  New Recovered  New Active Cases
# Date
# 2021-01-01       1956          20           1643               293
# 2021-01-02       1894          26           2280              -412
# 2021-01-03       1658          10           1691               -43
# 2021-01-04       1832          21           2527              -716

# %%
# mencari rata-rata masing-masing kolom numerik
mean =  df_new.mean()
mean
# Out:
# New Cases           1972.354735
# New Deaths            19.651685
# New Recovered       1960.504013
# New Active Cases      -7.800963
# dtype: float64

# %%
# mencari median/nilai tengah masing-masing kolom numerik
median = df_new.median()
median
# Out:
# New Cases           950.0
# New Deaths            6.0
# New Recovered       892.0
# New Active Cases     -8.0
# dtype: float64

# %%
# Modus merupakan nilai yang paling seiring muncul, oleh karenanya tidak semua kolom dapat dicari modusnya
# Mencari modus beberapa kolom yang mungkin memiliki nilai modus
modus = df_new['New Cases'].mode()
modus
# Out:
# 0    113
# Name: New Cases, dtype: int64

# %% [markdown]
# #### Cari Measure of Variance dari data tersebut.

# %%
df_new.describe().T
# Out:
#                   count         mean          std      min    25%    50%  \
# New Cases         623.0  1972.354735  2832.447572     14.0  184.0  950.0
# New Deaths        623.0    19.651685    33.085717      0.0    1.0    6.0
# New Recovered     623.0  1960.504013  3192.170957      0.0  188.0  892.0
# New Active Cases  623.0    -7.800963  2094.750905 -12150.0 -268.0   -8.0
#
#                      75%      max
# New Cases         2318.5  15825.0
# New Deaths          25.0    268.0
# New Recovered     2316.5  23872.0
# New Active Cases   272.5  10140.0

# %%
# Create a Histogram of Total Cases

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt


cases = df_new['New Deaths']
cases.plot.hist(title='New Cases Distribution', color='lightblue', bins=25)  
plt.axvline(cases.mean(), color='magenta', linestyle='dashed', linewidth=2)
plt.axvline(cases.median(), color='green', linestyle='dashed', linewidth=2)
plt.show()

# %%
# Get Skewness and Kurtosis Value

# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import scipy.stats as stats

numcols = ['New Cases', 'New Deaths','New Recovered','New Active Cases']
for col in numcols:
    print(df_new[col].name + ' skewness: ' + str(df_new[col].skew()))
    print(df_new[col].name + ' kurtosis: ' + str(df_new[col].kurt()))
    density = stats.gaussian_kde(df_new[col])
    n, x, _ = plt.hist(df_new[col], histtype='step', bins=25)  
    plt.plot(x, density(x)*6)
    plt.show()
    print('\n')
# Out:
# New Cases skewness: 2.4809760417715006
# New Cases kurtosis: 6.161457348493394
# New Deaths skewness: 3.624746532479949
# New Deaths kurtosis: 17.40610852711896
# New Recovered skewness: 3.345170965653603
# New Recovered kurtosis: 12.998384456027797
# New Active Cases skewness: -0.6467864371837981
# New Active Cases kurtosis: 10.66281659190351

# %% [markdown]
# ##### Range

# %%
numcols = ['New Cases', 'New Deaths','New Recovered','New Active Cases']

for col in numcols:
    print(df_new[col].name + ' range: ' + str(df_new[col].max() - df_new[col].min()))
# Out:
# New Cases range: 15811
# New Deaths range: 268
# New Recovered range: 23872
# New Active Cases range: 22290

# %% [markdown]
# ##### Percentile and Quartile

# %%
from scipy import stats

print('Percentile dari score 900 total cases : ',stats.percentileofscore(df_new['New Cases'], 900, 'weak'))
print('Percentile dari score 160 total deaths : ',stats.percentileofscore(df_new['New Deaths'], 160, 'weak'))
print('Percentile dari score 900 total recovered : ',stats.percentileofscore(df_new['New Recovered'], 900, 'weak'))
print('Percentile dari score 10 total active cases : ',stats.percentileofscore(df_new['New Active Cases'], 10, 'weak'))
# Out:
# Percentile dari score 900 total cases :  48.635634028892454
# Percentile dari score 160 total deaths :  99.19743178170144
# Percentile dari score 900 total recovered :  50.7223113964687
# Percentile dari score 10 total active cases :  54.25361155698234

# %%
# Display Box Plot of New Cases in Jakarta in >= 2021

# %matplotlib inline
from matplotlib import pyplot as plt


# Plot a box-whisker chart
df_new['New Cases'].plot(kind='box', title='Total Deaths Distribution', figsize=(10,8))
plt.show()

# %% [markdown]
# ##### Variance and Standard Deviation

# %%
# variance
print(df_new.var())
# Out:
# New Cases           8.022759e+06
# New Deaths          1.094665e+03
# New Recovered       1.018996e+07
# New Active Cases    4.387981e+06
# dtype: float64

# %%
# standard deviasi
print(df_new.std())
# Out:
# New Cases           2832.447572
# New Deaths            33.085717
# New Recovered       3192.170957
# New Active Cases    2094.750905
# dtype: float64
